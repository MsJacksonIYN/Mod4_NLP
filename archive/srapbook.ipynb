# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as snas
import requests
from bs4 import BeautifulSoup
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.common.exceptions import TimeoutException, StaleElementReferenceException
import time

# %%
test_url = 'https://www.nytimes.com/2010/02/24/dining/reviews/24rest.html'

# %%
"""
TEST REVIEWS
"""

def parse_urls(test_url):

    # GET HTML
    r = requests.get(test_url)
    c = r.content

    # CREATE BeautifulSoup Object
    soup = BeautifulSoup(c, 'html.parser')

    return parse_modern_reviews(soup)
    
parse_urls(test_url)
# Out:
# '\nTEST REVIEWS\n'
# {'name': 'Tanoreen',
#  'title': 'Tanoreen Restaurant in Bay Ridge, Brooklyn',
#  'review_url': 'https://www.nytimes.com/2010/02/24/dining/reviews/24rest.html',
#  'review_date': '20100223',
#  'reviewer': 'Sam Sifton',
#  'rating': '★',
#  'neighborhood': 'Bay Ridge',
#  'critic_pick': True,
#  'atmosphere': nan,
#  'sound': nan,
#  'recommendations': nan,
#  'menu': 'http://www.singlepage.com/tanoreen/menu',
#  'drinks': nan,
#  'price': '$$ (moderate)',
#  'hours': 'Tuesday to Friday,  noon to 10:30 p.m.;    Saturday, 10:30 a.m. to 10:30 p.m., .; Sunday, 10:30 a.m. to 10 p.m. ',
#  'reservations': 'Accepted',
#  'article_id': '1247467148081',
#  'keywords': 'Tanoreen',
#  'review': 'SATURDAY night in the neighborhood that once gave America fever, a Brooklyn that looks to itself for employment and has little time for the glittering island to the north.  A bridge rises out of it, a silver ramp, and you can see ocean beneath it, darkness running all the way to Portugal, and from there down the Mediterranean to the Middle East. Dinner time. Couples slide into tables at Tanoreen, Rawia Bishara’s marbled Levantine restaurant on the corner of Third Avenue and 76th Street in Bay Ridge, lately expanded from its tiny birth site in a storefront one block south. They join families with children, friends meeting friends. It is a lively, happy scene set beneath clouds of lamb, mint and garlic scents combined. Arabic music plays over speakers connected to a stereo set in back, and if this time it’s not the Lebanese siren Fairuz, singing “Al Bosta,” which evokes a village called Tanoreen, it might as  well be. Fairuz is known in the Middle East as “the neighbor to the moon.” Much the same could be said of Ms. Bishara, a Palestinian who grew up in Nazareth, in northern Israel, and who has been in the United States for close to four decades. She owns Tanoreen with her daughter, Jumana, whose eyes sparkle in the same almond shape as her mother’s. These  women rule over the kitchen and dining room with a kind of fierce benevolence. But it is the boundless cooking and endless, prodding hospitality of Ms. Bishara the elder that have defined the restaurant. At Tanoreen, she is celestial. Pickles come to the table first: delicate, sweet beets tangy with vinegar, lovely against a glass of mint tea. Palates jump to attention. They are greeted then by plates and plates of appetizers, or mezze. Sujok, an air-dried Armenian beef sausage scented with cumin and sumac, arrives in a small pool of spicy olive oil, bright with garlic. Eat a slice with a piece of the restaurant’s thin pita or crunchy zatar-spiced  bread, then take another bite of beet. Follow this with a bit of ethereal hummus, lightened with lemon juice to the point of being cloudlike, and some crazily flavorful tabbouleh, whose mint and bulgur combine into something that tastes very much like joy. There is baba ghanouj as well, smoky and rich in its eggplant base, and fattoush, a marvelous salad made of lettuce and cucumber, tomatoes and mint, sumac and parsley. It is dressed in olive oil, lemon and garlic, and layered in toasted wedges of pita, which Ms. Bishara uses throughout her cooking for texture, to great effect. Here now are some florets of cauliflower, browned to softness then allowed to cool, dressed in tahini and lines of pomegranate molasses, astringent sweetness against the flavors of sesame and vegetable. And a napoleon of eggplant, fried soft and sweet, then layered with baba ghanouj and festooned with tomatoes and — what’s this? — basil. Ms. Bishara’s translation of Middle Eastern cooking has Mediterranean accents, and occasional North American ones from her decades in the United States. And so the tang of cilantro enlivens some of her dishes, and the musk of basil, the welcome zing of jalapeño. In the opposite direction, she makes a simple spiced roast chicken with potatoes (and, for children, a mean plate of fried chicken fingers with French fries and ketchup), and a stuffed cabbage that your Uncle Murray who only eats tuna salad would devour. Tanoreen’s entrees are, in the main, less successful than the appetizers. Partly this is because the food doesn’t support the division of a meal into the Western tradition of starter and main course. After four or five delicious small plates, it’s difficult to do battle with a gristly lamb shank or one-acre lot of shepherd’s pie. It is smarter, perhaps, to order more from the appetizer lists — some small spinach or meat pies, for instance, and a plate of kibbe, the fried nuggets of ground lamb and spices that are meat’s answer to M&M’s, followed by some ridiculously flavorful stuffed grape leaves. Then  ...

# %%
def get_article_archived(soup):
    
    #Reviewer
    try:
        reviewer = soup.find('meta',{'name':'author'}).get('content')
    except:
        reviewer = float('nan')
    
    #Review Date
    try:
        rev_date = soup.find('meta',{'name':'pdate'}).get('content')
    except:
        rev_date = float('nan')
    
    #Keywords
    try:
        keywords = soup.find('meta',{'name':'news_keywords'}).get('content')
    except:
        keywords = float('nan')
        
    #Article ID
    try:
        article_id = soup.find('meta', itemprop='identifier').get('content')
    except:
        article_id = float('nan')
        
    #URL
    try: 
        url = soup.find('meta', {'property':'og:url'}).get('content')
    except:
        url = float('nan')
    
    
    #restaurant name & rating
    regex = re.compile("([a-zA-Z0-9_ ]+)(?:[ \n]+\*+ \[Rating: )([a-zA-Z0-9_ ]+)] [a-zA-Z0-9_ \('\)]*[, ]{0,2}([a-zA-Z0-9_ ,]*);")
    regex2 = re.compile("([a-zA-Z0-9_ .']+) ([A-Z]{4,12}) [a-zA-Z0-9_ \('\)]+, ([a-zA-Z0-9_ ,]+);")
    if regex.search(str(soup)):
        name = regex.search(str(soup))[1].strip()
        rating = regex.search(str(soup))[2]
        hood = regex.search(str(soup))[3]
    elif regex2.search(str(soup)):
        name = regex2.search(str(soup))[1].strip()
        rating = regex2.search(str(soup))[2]
        hood = regex2.search(str(soup))[3]
    elif soup.find('strong') and re.search('\*{1,5}',str(soup)) and re.search("\d+ [\w ()'.]+, ([\w (),]+);",str(soup)):
        name = soup.find('strong').get_text()
        rating = re.search('\*{1,5}',str(soup))[0]
        hood = re.search("\d+ [\w ()'.]+, ([\w (),]+);",str(soup))[1]
    elif soup.find('strong'):
        name = soup.find('strong').get_text()
        rating = soup.find('strong').find_parent().find_next_sibling().get_text()
        hood = soup.find('strong').find_parent().find_next_sibling().find_next_sibling().get_text()
    else:
        name = float('nan')
        rating = float('nan')
        hood = float('nan')    
    
    #Another Name Function (Maks)
    if name == 'nan':
        for par in soup.find_all('p', class_='story-body-text story-content'):
            string = str(par.get_text().strip())
            res = re.search('(^[A-Za-z]+)*$', string).group(1)
            if res:
                name = res
                
    #Atmosphere
    try:
        atmosphere = re.search('[ATMOSPHERatmospher]{10}[: -]+([\w\d \-,;\(\)]+).',str(soup))[1]
    except:
        atmosphere = float('nan')
    
    #Critic pick T/F
    cpick = float('nan')
    
    #Sound
    try:
        sound = re.search('[SOUNDsound]{5} [LEVlev]{5}[: -]+([\w\d \-,;\(\)]+).',str(soup))[1]
    except:
        sound = float('nan')
    
    #Menu Recommendations
    try:
        recs = re.search('[RECOMNDecomnd]{11} [DISHEdishe]{6}[: -]+([[\w\d \-,;\(\)]+).',str(soup))[1]
    except:
        recs = float('nan')
    
    #Menu Link
    menu_link = float('nan')
    
    #Drinks
    drinks = float('nan')
    
    #Price
    try:
        price = re.search("[PRICEprice]{5} [RANGErange]{5}[: -]+([\w\d \-,;\(\)$']+).", str(soup))[1]
    except:
        price = float('nan')
    
    #Hours
    try:
        hours = re.search("[HOURS]{5}[: -]+([\w\d \-,;\(\)$':]+).",str(soup))[1]
    except:
        hours = float('nan')
    
    #Reservations
    try:
        resis = re.search("[RESVATION]{12}[: -]+([\w\d \-,;\(\)$':]+).", str(soup))[1]
    except:
        resis = float('nan')
    
    #Review Text
    review = []
    for p in soup.find_all('p', class_='story-body-text story-content'):
        review.append(p.get_text())
    article = ' '.join(review)
    
    
    
    rev_dict = {'name': name,
                'review_url': url,
                'review_date': rev_date, 
                'reviewer': reviewer, 
                'rating': rating, 
                'neighborhood': hood,
                'critic_pick': cpick,
                'atmosphere': atmosphere,
                'sound': sound,
                'recommendations': recs,
                'menu': menu_link,
                'drinks': drinks,
                'price': price,
                'hours': hours,
                'reservations': resis,
                'review': article,
                'article_id': article_id,
                'keywords': keywords}
    
    return rev_dict

# %%
def parse_recent_reviews(soup):
    
    bad_str = ' - The New York Times'
    title = soup.find('title').get_text().replace(bad_str,'')
    
    # Extract review text
    article = []
        
    for p in soup.find_all('p', class_='css-18icg9x evys1bk0'):
            
        article.append(p.get_text())

    article = ' '.join(article)

    # Extract Restaurant Name, Stars + Neighborhood
    boa = soup.find('div', {'class': ['bottom-of-article', 'review-details restaurant-details']})

    # Restaurant Name
    name = boa.find('h4').get_text()

    # Restaurant Stars
    try:
        rating = boa.find('span', {'class': ['css-z4hz5', 'css-1y5uc8z']}).get_text()
    except:
        rating = boa.find('div', {'class': 'css-1y5uc8z'}).find('span').get_text()

    # Restaurant Neighborhood
    hood = boa.find('dd', class_='neighborhood').get_text()

    # Critic's Pick?
    if boa.find('span', {'class': 'css-14dcre2'}):
        cpick = True
    else:
        cpick = False

    # Restaurant Atmosphere
    try:
        atmosphere = boa.find('div', class_='atmosphere').find('dd').get_text()
    except:
        atmosphere = float('nan')

    # Sound
    try:
        sound = boa.find('div', class_='noiseLevel').find('dd').get_text()
    except:
        sound = float('nan')

    # Recommendations
    try:
        recs = boa.find('div', class_='recommendedDishes').find('dd').get_text()
    except:
        recs = float('nan')

    # Menu Link
    try:
        menu_link = boa.find('div', class_='menuLink').find('a', href=True)['href']
    except:
        menu_link = float('nan')

    # Drinks
    try:
        drinks = boa.find('div', class_='alcoholInfo').find('dd').get_text()
    except:
        drinks = float('nan')

    # Price
    try:
        price = boa.find('dd', class_='price').get_text()
    except:
        price = float('nan')

    # Hours
    try:
        hours = boa.find('dd', class_='hours').get_text()
    except:
        hours = float('nan')

    # Reservations
    try:
        resis = boa.find('dd', class_='reservations').get_text()
    except:
        resis = float('nan')

    # URL
    try:
        url = soup.find('meta', {'property':'og:url'}).get('content')
    except:
        url = float('nan')
            
    # Extract Meta Tags - Reviewer, Date, Keywords, Article_ID
    for tag in soup.find_all('meta'):

        if tag.get('name', None) == 'byl':
            reviewer = tag.get('content', None).replace('By ', '').strip()

        if tag.get('name', None) == 'pdate':
            rev_date = tag.get('content', None).strip()

        if tag.get('name', None) == 'news_keywords':
            keywords = tag.get('content', None).strip()

        if tag.get('name', None) == 'articleid':
            article_id = tag.get('content', None).strip()
            
    rev_dict = {'name': name,
                'title': title,
                'review_url': url,
                'review_date': rev_date, 
                'reviewer': reviewer, 
                'rating': rating, 
                'neighborhood': hood,
                'critic_pick': cpick,
                'atmosphere': atmosphere,
                'sound': sound,
                'recommendations': recs,
                'menu': menu_link,
                'drinks': drinks,
                'price': price,
                'hours': hours,
                'reservations': resis,
                'keywords': keywords,
                'article_id': article_id,
                'review': article}
    
    return rev_dict

# %%
def parse_broken_modern_reviews(soup):
    
    # Extract review text
    article = []
        
    for p in soup.find_all('p', class_='css-18icg9x evys1bk0'):
            
        article.append(p.get_text())

    article = ' '.join(article)

    # Extract Restaurant Name, Stars + Neighborhood
    boa = soup.find('p')
    print(boa)

    # Restaurant Name
    name = boa.find('p').find('strong').get_text()

    # Restaurant Stars
    rating = boa.find('span', {'class': ['css-z4hz5', 'css-1y5uc8z']}).get_text()

    # Restaurant Neighborhood
    try:
        hood = boa.find('dd', class_='neighborhood').get_text()
    except:
        pass
    
    # Critic's Pick?
    if boa.find('span', {'class': 'css-14dcre2'}):
        cpick = True
    else:
        cpick = False

    # Restaurant Atmosphere
    try:
        atmosphere = boa.find('p').find('strong', text_='ATMOSPHERE').get_text()
    except:
        atmosphere = float('nan')

    # Sound
    try:
        sound = boa.find('div', class_='noiseLevel').find('dd').get_text()
    except:
        sound = float('nan')

    # Recommendations
    try:
        recs = boa.find('div', class_='recommendedDishes').find('dd').get_text()
    except:
        recs = float('nan')

    # Menu Link
    try:
        menu_link = boa.find('div', class_='menuLink').find('a', href=True)['href']
    except:
        menu_link = float('nan')

    # Drinks
    try:
        drinks = boa.find('div', class_='alcoholInfo').find('dd').get_text()
    except:
        drinks = float('nan')

    # Price
    try:
        price = boa.find('dd', class_='price').get_text()
    except:
        price = float('nan')

    # Hours
    try:
        hours = boa.find('dd', class_='hours').get_text()
    except:
        hours = float('nan')

    # Reservations
    try:
        resis = boa.find('dd', class_='reservations').get_text()
    except:
        resis = float('nan')

    # URL
    try:
        url = soup.find('meta', {'property':'og:url'}).get('content')
    except:
        url = float('nan')
            
    # Extract Meta Tags - Reviewer, Date, Keywords, Article_ID
    for tag in soup.find_all('meta'):

        if tag.get('name', None) == 'byl':
            reviewer = tag.get('content', None).replace('By ', '').strip()

        if tag.get('name', None) == 'pdate':
            rev_date = tag.get('content', None).strip()

        if tag.get('name', None) == 'news_keywords':
            keywords = tag.get('content', None).strip()

        if tag.get('name', None) == 'articleid':
            article_id = tag.get('content', None).strip()
            
    rev_dict = {'name': name,
                'review_url': url,
                'review_date': rev_date, 
                'reviewer': reviewer, 
                'rating': rating, 
                'neighborhood': hood,
                'critic_pick': cpick,
                'atmosphere': atmosphere,
                'sound': sound,
                'recommendations': recs,
                'menu': menu_link,
                'drinks': drinks,
                'price': price,
                'hours': hours,
                'reservations': resis,
                'keywords': keywords,
                'article_id': article_id,
                'review': article}
    
    return rev_dict

# %%
def parse_modern_reviews(soup):
    
    bad_str = ' - The New York Times'
    title = soup.find('title').get_text().replace(bad_str,'')
    
    for tag in soup.find_all('meta'):
        #Reviewer
        if tag.get('name', None) == 'author':
            reviewer = tag.get('content', None).strip()
        #Review Date
        if tag.get('name', None) == 'pdate':
            rev_date = tag.get('content', None).strip()
        #Keywords
        if tag.get('name', None)== 'news_keywords':
            keywords = tag.get('content', None).strip()
    
    #End of Article summary information:
    EOA = soup.find('aside', class_='review-details restaurant-details')
    
    #restaurant name
    name = EOA.find('h4').get_text()

    #Rating
    if EOA.find('li', class_='critic-star-rating'):
        rating = EOA.find('li', class_='critic-star-rating').get_text()
    elif EOA.find('li', class_='critic-word-rating'):
        rating = EOA.find('li', class_='critic-word-rating').get_text()
    else:
        rating = float('nan')

    #Neighborhood
    hood = EOA.find('p', itemprop='addressLocality').get_text()

    #Critic pick T/F
    if EOA.find('li', class_='critics-pick'):
        cpick = True
    else:
        cpick = False
    
    #Atmosphere
    try:
        atmosphere = EOA.find('span', text='Atmosphere').parent.find('span', itemprop='review').get_text()
    except:
        atmosphere = float('nan')
    
    #Sound
    try:
        sound = EOA.find('span', text='Sound').parent.find('span', itemprop='review').get_text()
    except:
        sound = float('nan')
    
    #Menu Recommendations
    try:
        recs = EOA.find('span', text='Recommended Dishes').parent.find('span', itemprop='menu').get_text()
    except:
        recs = float('nan')
    
    #Menu Link
    try:
        menu_link = EOA.find('span', text='Menu').parent.find('span', itemprop='menu').find('a').get('href')
    except:
        menu_link = float('nan')
    
    #Drinks
    try:
        drinks = EOA.find('span', text='Drinks and Wine').parent.find('span', itemprop='menu').get_text()
    except:
        drinks = float('nan')
    
    #Price
    try:
        price = EOA.find('span', itemprop='priceRange').get_text()
    except:
        price = float('nan')
    
    #Hours
    try:
        hours = EOA.find('time').get('datetime')
    except:
        hours = float('nan')
    
    #Reservations
    try:
        resis = EOA.find('span', itemprop='acceptsReservations').get_text()
    except:
        resis = float('nan')
    
    #Review Text
    review = []
    
    for p in soup.find_all('p', class_='story-body-text story-content'):
        if p.get('data-para-count') == '8':
            break
        else:
            review.append(p.get_text())
            
    article = ' '.join(review)

    #Article ID
    article_id = soup.find('meta', itemprop='identifier').get('content')
    
    #Review URL
    url = soup.find('meta', {'property':'og:url'}).get('content')
    
    rev_dict = {'name': name,
                'title': title,
                'review_url': url,
                'review_date': rev_date, 
                'reviewer': reviewer, 
                'rating': rating, 
                'neighborhood': hood,
                'critic_pick': cpick,
                'atmosphere': atmosphere,
                'sound': sound,
                'recommendations': recs,
                'menu': menu_link,
                'drinks': drinks,
                'price': price,
                'hours': hours,
                'reservations': resis,
                'article_id': article_id,
                'keywords': keywords,
                'review': article}
    
    return rev_dict

# %%
df_og = pd.read_csv('reviews.csv', index_col='Unnamed: 0')

# %%
df_all_reviews = pd.read_csv('all_reviews.csv',index_col='Unnamed: 0')

# %%
df_og.head()
# Out:
#                 name  rating     review_date    reviewer     neighborhood  \
# 0              Hanon  2 star    May 21, 2019  Pete Wells     Williamsburg
# 1          Del Posto  3 star    May 14, 2019  Pete Wells          Chelsea
# 2  The Freakin Rican  1 star     May 7, 2019  Pete Wells          Astoria
# 3              Wayan  2 star  April 23, 2019  Pete Wells           NoLIta
# 4              Niche  1 star  April 16, 2019  Pete Wells  Lower East Side
#
#                      cuisine  \
# 0                   Japanese
# 1                    Italian
# 2  Caribbean, Latin American
# 3                 Indonesian
# 4                   Japanese
#
#                                        review_link_1  \
# 0  https://www.nytimes.com/2019/05/21/dining/hano...
# 1  https://www.nytimes.com/2019/05/14/dining/del-...
# 2  https://www.nytimes.com/2019/05/07/dining/the-...
# 3  https://www.nytimes.com/2019/04/23/dining/waya...
# 4  https://www.nytimes.com/2019/04/16/dining/nich...
#
#                                        review_link_2
# 0  https://www.nytimes.com/2019/05/21/dining/hano...
# 1  https://www.nytimes.com/2019/05/14/dining/del-...
# 2  https://www.nytimes.com/2019/05/07/dining/the-...
# 3  https://www.nytimes.com/2019/04/23/dining/waya...
# 4  https://www.nytimes.com/2019/04/16/dining/nich...

# %%
df_og = df_og.rename(columns={'review_link_1': 'review_url'})

# %%
df_og.head()
# Out:
#                 name  rating     review_date    reviewer     neighborhood  \
# 0              Hanon  2 star    May 21, 2019  Pete Wells     Williamsburg
# 1          Del Posto  3 star    May 14, 2019  Pete Wells          Chelsea
# 2  The Freakin Rican  1 star     May 7, 2019  Pete Wells          Astoria
# 3              Wayan  2 star  April 23, 2019  Pete Wells           NoLIta
# 4              Niche  1 star  April 16, 2019  Pete Wells  Lower East Side
#
#                      cuisine  \
# 0                   Japanese
# 1                    Italian
# 2  Caribbean, Latin American
# 3                 Indonesian
# 4                   Japanese
#
#                                           review_url  \
# 0  https://www.nytimes.com/2019/05/21/dining/hano...
# 1  https://www.nytimes.com/2019/05/14/dining/del-...
# 2  https://www.nytimes.com/2019/05/07/dining/the-...
# 3  https://www.nytimes.com/2019/04/23/dining/waya...
# 4  https://www.nytimes.com/2019/04/16/dining/nich...
#
#                                        review_link_2
# 0  https://www.nytimes.com/2019/05/21/dining/hano...
# 1  https://www.nytimes.com/2019/05/14/dining/del-...
# 2  https://www.nytimes.com/2019/05/07/dining/the-...
# 3  https://www.nytimes.com/2019/04/23/dining/waya...
# 4  https://www.nytimes.com/2019/04/16/dining/nich...

# %%
df_reviews = df_all_reviews[['review_url', 'review', 'price']]

# %%
df_reviews.head(100)
# Out:
# 93  https://www.nytimes.com/2006/03/01/dining/revi...
# 94  https://www.nytimes.com/2004/02/04/dining/rest...
# 95  https://www.nytimes.com/1999/07/21/dining/rest...
# 96  https://www.nytimes.com/2002/06/19/dining/rest...
# 97  https://www.nytimes.com/2004/12/29/dining/revi...
# 98  https://www.nytimes.com/2016/04/06/dining/le-t...
# 99  https://www.nytimes.com/2003/05/07/dining/rest...
#
#                                                review  \
# 0   AT many restaurants I've received tutorials on...
# 1   JEAN-CLAUDE IZZO wrote a terrific series of Fr...
# 2   PERHAPS no other recently opened restaurant ra...
# 3   ITALIAN cooking is about a lot more than pasta...
# 4   IT is a strange feeling, sitting in Má Pêche o...
# 5   POP is a funny name for a restaurant. It's a h...
# 6   LIKE drawing a circle or walking a high wire, ...
# 7   IT'S easy to see the bad in things and harder ...
# 8   SOME chefs storm into the city like an invadin...
# 9   RESTAURANTS are like small cruise ships, with ...
# 10  THE Marseille hovering behind Marseille the re...
# 11  Standing on a drawbridge one night early this ...
# 12  IF you happen to follow Italian politics, you ...
# 13  WHEN Jean Georges opened along the northern cu...
# 14  TO the question of how a restaurant can season...
# 15  FOR a while it seemed that most of the restaur...
# 16  WHEN Patroon opened in Midtown in 1996, it rev...
# 17  THE restaurant Peter Luger has been around for...
# 18  Ever since Rich Torrisi and Mario Carbone bega...
# 19  THE bright lights of this big city stoke diffe...
# 20  CREATIVE people should never explain their pro...
# 21  IF you want to make the acquaintance of your d...
# 22  CAN a restaurant predict the future? Delmonico...
# 23  Before Jeju Noodle Bar came along in September...
# 24  GREAT restaurants may start out that way. But ...
# 25  The emails from New Delhi began last spring. A...
# 26  FATTY ’CUE, Zakary Pelaccio’s funky new barbec...
# 27  IN Paris, the Hôtel Plaza Athénée has Alain Du...
# 28  IT says something about Manhattan today that j...
# 29  WHEN last we left the restless young chef Jaso...
# ..                                                ...
# 70  THE new dining room at the Morgan Library and ...
# 71  AN empty plate is a canvas, and it inspires tw...
# 72  THERE was a time when you could walk into just...
# 73  COBI LEVY was greeting guests at the top of th...
# 74  SOME restaurants take a while to find their fo...
# 75  IF anyone has cracked the code for high-end re...
# 76  Sitting at the upstairs bar, one of the best p...
# 77  Visitors to Hong Kong who have an appreciation...
# 78  THE best dish I had at Sip Sak, an artfully co...
# 79  VENETIAN glass dangles from the ceiling, Campa...
# 80  TO understand why, after all these years, Unio...
# 81  WHEN a restaurant scene is as hectic and aggre...
# 82  THE lack of good restaurants in Brooklyn Heigh...
# 83  THE outlines of the trend are not clear yet, a...
# 84  You enter Tom Colicchio’s new restaurant near ...
# 85  YOU may hardly believe it, walking in through ...
# 86  TEN years ago this summer, Anita Lo opened Ann...
# 87  The lady had dropped her napkin. More accurate...
# 88  IT would be easy to feel cynical about Mai Hou...
# 89  DANIEL BOULUD wants his guests to take off the...
# 90  SOMEWHERE around 9:40 p.m., our waiter at Unio...
# 91  BY all rights New York should have more places...
# 92  The best way to enter the Albanian restaurant ...
# 93  MUCH has been said about the marble, mahogany ...
# 94  CRISP and angry lobster. ''Bronx style'' filet...
# 95  SLEEK, slinky creatures crowd the bar at Vanda...
# 96  BARBECUE and passion go together like jazz and...
# 97  Correction Appended I COULD reach deep into a ...
# 98  The premodern look in restaurants and bars tha...
# 99  DOUGLAS RODRIGUEZ knows how to give a party. S...
#
#                                                 price
# 0   For lunch, three-course prix fixe, $60; limite...
# 1                                     $$$ (expensive)
# 2                             Cold dishes, $11 to $34
# 3                                     $$$ (expensive)
# 4                                     $$$ (expensive)
# 5   Dinner, appetizers, $9 to $15 ($85 for one oun...
# 6                               $$$$ (very expensive)
# 7                                     $$$ (expensive)
# 8                                     $$$ (expensive)
# 9   Dinner, appetizers, $8 to $15; pizza, pasta an...
# 10  Appetizers, $7 to $12; entrees, $16 to $24; de...
# 11                                      $$ (moderate)
# 12             Lunch appetizers and salads, $7 to $14
# 13  Two-course lunch prix fixe, not including dess...
# 14                                      $$ (moderate)
# 15  Mezedes (small plates) and larger appetizers, ...
# 16                              Lunch, appetizers, $8
# 17                              $$$$ (very expensive)
# 18                                    $$$ (expensive)
# 19  Appetizers, $8 to $11; pastas, $14 to $16; ent...
# 20                              $$$$ (very expensive)
# 21  Lunch appetizers, $6 to $15; entrees, $10 to $...
# 22  Appetizers, $8 to $16 ($32 for the cold seafoo...
# 23                                      $$ (moderate)
# 24                                                NaN
# 25                              $$$$ (very expensive)
# 26                                      $$ (moderate)
# 27  Lunch, appetizers, $11 to $19; entrees, $21 to...
# 28                              Lunch, appetizers, $5
# 29                                    $$$ (expensive)
# ..                                                ...
# 70  Appetizers, $6 to $12; entrees, $15 to $28; de...
# 71                                     Appetizers, $7
# 72  Munchies from $5 to $20; side dishes, $4 to $6...
# 73                              $$$$ (very expensive)
# 74  Lunch, appetizers, $4 to $5; entrees, $11 to $...
# 75  Lunch appetizers, $10 to $17; salads, sandwich...
# 76                              $$$$ (very expensive)
# 77                                    $ (inexpensive)
# 78                          Appetizers and salads, $4
# 79             Lunch appetizers and salads, $9 to $19
# 80                                                NaN
# 81  Dinner, appetizers, $8 to $14; entrees, $18 to...
# 82                                    $$$ (expensive)
# 83  Dinner, appetizers, $8 to $16; entrees, $23 to...
# 84                              $$$$ (very expensive)
# 85                                    $$$ (expensive)
# 86                              $$$$ (very expensive)
# 87                              $$$$ (very expensive)
# 88                                                NaN
# 89  Lunch appetizers, $9 to $17; main courses, $23...
# 90  Three-course prix fixe menu, $68; five-course ...
# 91  Lunch tapas, larger appetizers and salads, $6 ...
# 92                                      $$ (moderate)
# 93  Antipasti, $13 to $19; pasta and risotto dishe...
# 94  Appetizers, $10 to $18; entrees, $20 to $36; d...
# 95  Appetizers, $8 to $15; entrees, $19 to $26; de...
# 96                                     Appetizers, $4
# 97  $350 prix fixe, excluding tax, tips and beverages
# 98                                    $$$ (expensive)
# 99  Lunch, appetizers, $4 to $13; entrees, $10 to ...
#
# [100 rows x 3 columns]

# %%
df_final = df_og.merge(df_reviews, on='review_url', how='left')

# %%
df_final
# Out:
#                             name     rating     review_date       reviewer  \
# 0                          Hanon     2 star    May 21, 2019     Pete Wells
# 525                  Le Colonial     2 star   April 1, 1994    Ruth Reichl
# 526                Tang Pavilion     2 star  March 18, 1994    Ruth Reichl
# 527          Kang Suh Restaurant     2 star   Oct. 22, 1993    Ruth Reichl
# 528                         Orso     2 star    June 4, 1993   Bryan Miller
# 529                    Il Mulino     2 star   June 19, 1992   Bryan Miller
# 530                   Da Umberto     2 star   Aug. 30, 1991   Bryan Miller
# 531           Cafe Un Deux Trois     1 star   April 5, 1991   Bryan Miller
# 532                   Les Halles     2 star   Feb. 15, 1991   Bryan Miller
# 533          Trattoria dell'Arte     1 star   Jan. 20, 1989   Bryan Miller
# 534                Victor's Cafe     1 star  Sept. 18, 1987   Bryan Miller
# 535    Ambassador Grill & Lounge     1 star    Oct. 3, 1986   Bryan Miller
# 536             La Boite en Bois     1 star  Sept. 27, 1985   Bryan Miller
# 537                   Gargiulo's   0.5 star   Aug. 24, 1984  Marian Burros
# 538   Kodama Japanese Restaurant     1 star   July 29, 1983  Mimi Sheraton
#
#                       neighborhood                    cuisine  \
# 0                     Williamsburg                   Japanese
# 1                          Chelsea                    Italian
# 2                          Astoria  Caribbean, Latin American
# 3                           NoLIta                 Indonesian
# 4                  Lower East Side                   Japanese
# 5                       Park Slope                     Korean
# 6                     West Village                   American
# 7                     East Village             Italian, Pizza
# 8                Flatiron district                   Japanese
# 9                          Belmont          Eastern European
# 10                    East Village                 Vietnamese
# 11                   Crown Heights                   American
# 12                    West Village                     French
# 13                      Greenpoint          American, English
# 14                           NoMad            French, Italian
# 15                         Midtown                 Sandwiches
# 16                         Chelsea                     Korean
# 17                         Midtown          American, English
# 18                         Midtown                    Seafood
# 19                     Cobble Hill                    Seafood
# 20                Long Island City                     Indian
# 21                    Williamsburg                    Italian
# 22                 Upper West Side                      Pizza
# 23                         Midtown          African, American
# 24                    East Village                    Chinese
# 25                     Murray Hill                     Korean
# 26              Financial District                     French
# 27                         Midwood          Eastern European
# 28                       Chinatown                  Malaysian
# 29                         TriBeCa                   Japanese
# ..                             ...                        ...
# 509                   Midtown East                    Russian
# 510                        TriBeCa                    Italian
# 511                Upper East Side                    Mexican
# 512                   Midtown East                    Italian
# 513                Upper East Side                  Brazilian
# 514                        Midtown               New American
# 515                   Midtown East      Seafood, Steak Houses
# 516                   Midtown East            Japanese, Sushi
# 517                  Midtown South                   Japanese
# 518                           SoHo                    Italian
# 519                           SoHo                    Seafood
# 520                           SoHo               New American
# 521                Upper East Side                     French
# 522                           SoHo                    Italian
# 523                   Midtown East                    Italian
# 524                        TriBeCa                    Italian
# 525                   Midtown East                 Vietnamese
# 526                        Midtown                    Chinese
# 527                      Koreatown                     Korean
# 528                        Clinton                    Italian
# 529              Greenwich Village                    Italian
# 530                        Chelsea                    Italian
# 531  Times Square Theatre District                     French
# 532                       Kips Bay                     French
# 533                        Midtown                    Italian
# 534                        Midtown             Latin American
# 535                   Midtown East               New American
# 536                Upper West Side                     French
# 537                   Coney Island                    Italian
# 538                        Clinton            Japanese, Sushi
#
#                                             review_url  \
# 0    https://www.nytimes.com/2019/05/21/dining/hano...
# 525  https://www.nytimes.com/1994/04/01/arts/restau...
# 526  https://www.nytimes.com/1994/03/18/arts/restau...
# 527  https://www.nytimes.com/1993/10/22/arts/restau...
# 528  https://www.nytimes.com/1993/06/04/arts/restau...
# 529  https://www.nytimes.com/1992/06/19/arts/restau...
# 530  https://www.nytimes.com/1991/08/30/arts/restau...
# 531  https://www.nytimes.com/1991/04/05/arts/restau...
# 532  https://www.nytimes.com/1991/02/15/arts/restau...
# 533  https://www.nytimes.com/1989/01/20/arts/restau...
# 534  https://www.nytimes.com/1987/09/18/arts/restau...
# 535  https://www.nytimes.com/1986/10/03/arts/restau...
# 536  https://www.nytimes.com/1985/09/27/arts/restau...
# 537  https://www.nytimes.com/1984/08/24/arts/restau...
# 538  https://www.nytimes.com/1983/07/29/arts/restau...
#
#                                                 review
# 0    Hanon, a new udon shop in Williamsburg, Brookl...
# 1    More than a year ago, I was on the verge of re...
# 2    It is true that the bacalaitos at the Freakin ...
# 3    If you ate at Spice Market before it closed tw...
# 4    In 2012 and 2013, when people were lining up a...
# 5    Looking around Haenyeo’s dining room one night...
# 6    I’m starting to think the American cult of che...
# 7    When I left my home state of Rhode Island at 1...
# 8    Before I tell you about the seasonally attuned...
# 9    The best way to enter the Albanian restaurant ...
# 10   The main attraction at Madame Vo BBQ, now two ...
# 11   Part of the fun of eating at a pop-up is the t...
# 12   The great Midtown shrines to French cuisine we...
# 13   Cherry Point sits on Manhattan Avenue in Green...
# 14   Dated was the word one friend used after going...
# 15   The fancy mall in the Time Warner Center known...
# 16                                                 NaN
# 17   Something seems to be going wrong at Bluebird ...
# 18   There is a good case to be made for not review...
# 19   Alex Raij and Eder Montero met while working i...
# 20   Something has been missing from New York’s cur...
# 21   Almost everybody is calling Misi, the latest e...
# 22   For most of its time on earth, the New York sl...
# 23   Earlier this year Henry, a new restaurant in t...
# 24   The rise of Sichuan food in New York has made ...
# 25   A card is set down in front of you before each...
# 26   Shrinking modesty is not the normal attitude f...
# 27   During the five years Village Cafe has been op...
# 28   Sometimes when I am waiting, and waiting, for ...
# 29                                                 NaN
# ..                                                 ...
# 509  EVERY time I eat caviar I think of M. F. K. Fi...
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
# 515                                                NaN
# 516                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
# 524                                                NaN
# 525                                                NaN
# 526                                                NaN
# 527                                                NaN
# 528                                                NaN
# 529                                                NaN
# 530                                                NaN
# 531                                                NaN
# 532                                                NaN
# 533                                                NaN
# 534                                                NaN
# 535                                                NaN
# 536                                                NaN
# 537                                                NaN
# 538                                                NaN
#
# [539 rows x 9 columns]

# %%
df_final.to_csv('reviews_final.csv')

# %%
df_final.isnull().sum()
# Out:
# name               0
# rating             0
# review_date        0
# reviewer           0
# neighborhood       3
# cuisine            0
# review_url         0
# review_link_2      0
# review           139
# dtype: int64

# %%
df_final.shape
# Out:
# (539, 9)
